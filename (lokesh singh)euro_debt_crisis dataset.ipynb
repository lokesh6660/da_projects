# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [raw]
# import different library to analysis the dataset
# ------>
# pandas,matplotlib,seaborn

# %% [markdown]
# # import csv data set

# %%
df1=pd.read_csv(r"C:\Users\hp\Desktop\P6-EuroDebtCrisis.csv")
df1
# Out:
#          Creditor         Debtor  Amount         Risk
# 0           Japan  United States  796.00       Stable
# 1          France          Italy  366.00    High Risk
# 2         Britain  United States  345.00       Stable
# 3           Spain        Britain  326.00       Stable
# 4         Germany  United States  324.00       Stable
# 5          France  United States  322.00       Stable
# 6         Germany        Britain  321.00       Stable
# 7           Spain  United States  163.00       Stable
# 8          France          Spain  118.00  Medium Risk
# 9           Italy        Germany  111.00       Stable
# 10          Japan        Germany   88.50       Stable
# 11          Spain       Portugal   62.00    High Risk
# 12        Germany          Spain   57.60  Medium Risk
# 13         France         Greece   53.90    High Risk
# 14         France        Germany   53.80       Stable
# 15        Germany        Ireland   48.90    High Risk
# ...

# %% [markdown]
# # observe the data set

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Creditor  45 non-null     object
#  1   Debtor    45 non-null     object
#  2   Amount    45 non-null     float64
#  3   Risk      45 non-null     object
# dtypes: float64(1), object(3)
# memory usage: 1.5+ KB

# %% [markdown]
# ##################
#
# #### amount is an numerical data which having data type "float64",
# and other column is catagorical data.
# like:Creditor,Debtor and Risk
#
# ##################

# %%
df1.describe()
# Out:
#            Amount
# count   45.000000
# mean    86.744222
# std    154.444738
# min      0.340000
# 25%      3.770000
# 50%     19.400000
# 75%     62.000000
# max    796.000000

# %% [raw]
# #############
#
# this function probide amount or(numerical data) information
# like : count,mean,min,max and percentile data
#
# #############

# %%
#finding number of column and its data 

#########

df1.columns
# Out:
# Index(['Creditor', 'Debtor', 'Amount', 'Risk'], dtype='object')

# %%
df1.isnull().sum()
# Out:
# Creditor    0
# Debtor      0
# Amount      0
# Risk        0
# dtype: int64

# %% [raw]
# ##########
#
# this data set has no null value in any column
# ----->then we need to observ each column individual

# %%
df1["Creditor"]
# Out:
# 0             Japan
# 1            France
# 2           Britain
# 3             Spain
# 4           Germany
# 5            France
# 6           Germany
# 7             Spain
# 8            France
# 9             Italy
# 10            Japan
# 11            Spain
# 12          Germany
# 13           France
# 14           France
# 15          Germany
# 16            Japan
# 17          Germany
# 18            Japan
# 19          Britain
# 20            Japan
# 21          Britain
# 22          Britain
# 23          Germany
# 24            Japan
# 25           France
# 26           France
# 27          Ireland
# 28    United States
# 29         Portugal
# 30            Spain
# 31           France
# 32          Ireland
# 33         Portugal
# 34            Italy
# 35    United States
# 36    United States
# 37            Italy
# 38            Japan
# 39            Japan
# 40            Italy
# 41            Spain
# 42          Britain
# 43         Portugal
# 44          Ireland
# ...

# %%
df1["Debtor"]
# Out:
# 0     United States
# 1             Italy
# 2     United States
# 3           Britain
# 4     United States
# 5     United States
# 6           Britain
# 7     United States
# 8             Spain
# 9           Germany
# 10          Germany
# 11         Portugal
# 12            Spain
# 13           Greece
# 14          Germany
# 15          Ireland
# 16            Italy
# 17         Portugal
# 18          Britain
# 19            Italy
# 20            Spain
# 21           France
# 22         Portugal
# 23           Greece
# 24          Ireland
# 25         Portugal
# 26          Ireland
# 27          Britain
# 28          Ireland
# 29           Greece
# 30            Italy
# 31            Japan
# 32            Spain
# 33          Ireland
# 34           Greece
# 35            Italy
# 36           Greece
# 37          Ireland
# 38         Portugal
# 39           Greece
# 40         Portugal
# 41           Greece
# 42           Greece
# 43    United States
# 44           Greece
# ...

# %%
df1['Amount']
# Out:
# 0     796.00
# 1     366.00
# 2     345.00
# 3     326.00
# 4     324.00
# 5     322.00
# 6     321.00
# 7     163.00
# 8     118.00
# 9     111.00
# 10     88.50
# 11     62.00
# 12     57.60
# 13     53.90
# 14     53.80
# 15     48.90
# 16     38.80
# 17     32.50
# 18     28.20
# 19     26.00
# 20     25.90
# 21     22.40
# 22     19.40
# 23     19.30
# 24     18.90
# 25     18.30
# 26     17.30
# 27     12.00
# 28     11.10
# 29     10.10
# 30      9.79
# 31      7.73
# 32      6.38
# 33      3.77
# 34      3.22
# 35      3.16
# 36      3.10
# 37      2.83
# 38      2.18
# 39      1.37
# 40      0.87
# 41      0.78
# 42      0.55
# 43      0.52
# 44      0.34
# Name: Amount, dtype: float64

# %%
df1.mode(dropna=False)
# Out:
#    Creditor  Debtor  Amount       Risk
# 0    France  Greece    0.34  High Risk
# 1     Japan     NaN    0.52        NaN
# 2       NaN     NaN    0.55        NaN
# 3       NaN     NaN    0.78        NaN
# 4       NaN     NaN    0.87        NaN
# 5       NaN     NaN    1.37        NaN
# 6       NaN     NaN    2.18        NaN
# 7       NaN     NaN    2.83        NaN
# 8       NaN     NaN    3.10        NaN
# 9       NaN     NaN    3.16        NaN
# 10      NaN     NaN    3.22        NaN
# 11      NaN     NaN    3.77        NaN
# 12      NaN     NaN    6.38        NaN
# 13      NaN     NaN    7.73        NaN
# 14      NaN     NaN    9.79        NaN
# 15      NaN     NaN   10.10        NaN
# 16      NaN     NaN   11.10        NaN
# 17      NaN     NaN   12.00        NaN
# 18      NaN     NaN   17.30        NaN
# 19      NaN     NaN   18.30        NaN
# 20      NaN     NaN   18.90        NaN
# 21      NaN     NaN   19.30        NaN
# 22      NaN     NaN   19.40        NaN
# ...

# %% [raw]
# # we observe
# all column has normal data
#
# ###########
#
# Creditor has mode="France" and "Japan"
# Debtor has mode="Greece"
# and
# Risk has mode="High Risk"

# %%
#draw heat map on null value

# %%
sns.heatmap(df1.isnull())
# Out:
# <AxesSubplot:>

# %% [raw]
# ############
#
# we find no empty data in the data set as shown in the heat map

# %%
#now we need  to find correlation betwen the columns

df1.corr()
# Out:
#         Amount
# Amount     1.0

# %% [raw]
# ###########
#
# we can not find any correlation between the data set columns
# because all other columns has catagorical data
#
# ########

# %%
#we need to find to take some sample data
df1.sample(5)
# Out:
#     Creditor         Debtor  Amount       Risk
# 43  Portugal  United States    0.52     Stable
# 27   Ireland        Britain   12.00     Stable
# 37     Italy        Ireland    2.83  High Risk
# 3      Spain        Britain  326.00     Stable
# 25    France       Portugal   18.30  High Risk

# %% [raw]
# ##########
# now we analysis data using chart and collect information about euro debt crisis
#
# ##########

# %%
df1["Creditor"].nunique()
# Out:
# 9

# %%
df1["Debtor"].nunique()
# Out:
# 10

# %%
a=df1["Creditor"].unique()
a
# Out:
# array(['Japan', 'France', 'Britain', 'Spain', 'Germany', 'Italy',
#        'Ireland', 'United States', 'Portugal'], dtype=object)

# %%
b=df1["Debtor"].unique()
b
# Out:
# array(['United States', 'Italy', 'Britain', 'Spain', 'Germany',
#        'Portugal', 'Greece', 'Ireland', 'France', 'Japan'], dtype=object)

# %% [markdown]
# ########
#
# we draw jointplot to find the the relationship between each country of "debtor" and "creditor"

# %%
sns.jointplot(x="Creditor",y="Debtor",data=df1)

# %% [raw]
# ###
#
# in this graph we clearly see that each country of creditor has how many number
# of debtot or vic-versa

# %%
df1.groupby(["Creditor","Debtor"]).mean().iloc[1:]
# Out:
#                              Amount
# Creditor      Debtor
# Britain       Greece           0.55
#               Italy           26.00
#               Portugal        19.40
#               United States  345.00
# France        Germany         53.80
#               Greece          53.90
#               Ireland         17.30
#               Italy          366.00
#               Japan            7.73
#               Portugal        18.30
#               Spain          118.00
#               United States  322.00
# Germany       Britain        321.00
#               Greece          19.30
#               Ireland         48.90
#               Portugal        32.50
#               Spain           57.60
#               United States  324.00
# Ireland       Britain         12.00
#               Greece           0.34
#               Spain            6.38
# Italy         Germany        111.00
#               Greece           3.22
#               Ireland          2.83
# ...

# %%
df1.groupby(["Debtor","Creditor"]).mean().iloc[1:]
# Out:
#                              Amount
# Debtor        Creditor
# Britain       Ireland         12.00
#               Japan           28.20
#               Spain          326.00
# France        Britain         22.40
# Germany       France          53.80
#               Italy          111.00
#               Japan           88.50
# Greece        Britain          0.55
#               France          53.90
#               Germany         19.30
#               Ireland          0.34
#               Italy            3.22
#               Japan            1.37
#               Portugal        10.10
#               Spain            0.78
#               United States    3.10
# Ireland       France          17.30
#               Germany         48.90
#               Italy            2.83
#               Japan           18.90
#               Portugal         3.77
#               United States   11.10
# Italy         Britain         26.00
#               France         366.00
# ...

# %% [markdown]
# # observation with graph and groupby function

# %% [raw]
# 1.japan and france country in creditor has "8" debtor country
# France	Germany	53.80
#         Greece	53.90
#         Ireland	17.30
#         Italy	366.00
#         Japan	7.73
#         Portugal	18.30
#         Spain	118.00
#         United States	322.00
#
#         And
#
# Japan	Britain	28.20
#         Germany	88.50
#         Greece	1.37
#         Ireland	18.90
#         Italy	38.80
#         Portugal	2.18
#         Spain	25.90
#         United States	796.00
#
# 2. Greece country in debtor has "9" creditor country
# Greece	Britain	0.55
#         France	53.90
#         Germany	19.30
#         Ireland	0.34
#         Italy	3.22
#         Japan	1.37
#         Portugal	10.10
#         Spain	0.78
#         United States	3.10
#
# 3.lowest creditor country has "3" debtor country
# ----->United States,Portugal and Ireland
#
# 4.lowest debtor country has "1" creditor country
# ----->japan and france

# %%
creditor=df1["Creditor"]
creditor
# Out:
# 0             Japan
# 1            France
# 2           Britain
# 3             Spain
# 4           Germany
# 5            France
# 6           Germany
# 7             Spain
# 8            France
# 9             Italy
# 10            Japan
# 11            Spain
# 12          Germany
# 13           France
# 14           France
# 15          Germany
# 16            Japan
# 17          Germany
# 18            Japan
# 19          Britain
# 20            Japan
# 21          Britain
# 22          Britain
# 23          Germany
# 24            Japan
# 25           France
# 26           France
# 27          Ireland
# 28    United States
# 29         Portugal
# 30            Spain
# 31           France
# 32          Ireland
# 33         Portugal
# 34            Italy
# 35    United States
# 36    United States
# 37            Italy
# 38            Japan
# 39            Japan
# 40            Italy
# 41            Spain
# 42          Britain
# 43         Portugal
# 44          Ireland
# ...

# %%
plt.figure(figsize=(10,9))
plt.hist(creditor,color="pink")
plt.xlabel("creditor")
plt.ylabel("no of occer")
# Out:
# Text(0, 0.5, 'no of occer')

# %% [raw]
# ######
#
# this histogram show that which country of creditor is maximum number of
# frequency in the data.
#
# ---->japan and france has max number of frequency
#
# ######

# %%
debtor=df1["Debtor"]
debtor
# Out:
# 0     United States
# 1             Italy
# 2     United States
# 3           Britain
# 4     United States
# 5     United States
# 6           Britain
# 7     United States
# 8             Spain
# 9           Germany
# 10          Germany
# 11         Portugal
# 12            Spain
# 13           Greece
# 14          Germany
# 15          Ireland
# 16            Italy
# 17         Portugal
# 18          Britain
# 19            Italy
# 20            Spain
# 21           France
# 22         Portugal
# 23           Greece
# 24          Ireland
# 25         Portugal
# 26          Ireland
# 27          Britain
# 28          Ireland
# 29           Greece
# 30            Italy
# 31            Japan
# 32            Spain
# 33          Ireland
# 34           Greece
# 35            Italy
# 36           Greece
# 37          Ireland
# 38         Portugal
# 39           Greece
# 40         Portugal
# 41           Greece
# 42           Greece
# 43    United States
# 44           Greece
# ...

# %%
plt.figure(figsize=(10,9))
plt.hist(debtor,color="g")
plt.xlabel("debtor")
plt.ylabel("no of occer")
# Out:
# Text(0, 0.5, 'no of occer')

# %% [raw]
# #######
#
# this histogram show that which country of debtor is maximum number of
# frequency in the data.
#
# ---->greece is max number of frequency
#
# #######

# %%
sns.jointplot(x="Creditor",y="Debtor",hue="Risk",data=df1,kind="hist",height=10)

# %% [markdown]
# # observation 2

# %% [raw]
# ######
#
# this joint plot show the relation between debtor and creditor accoding to
# "risk" in the data set.
#
# this plot easy to understand which country has high risk,low risk, medium risk and stable
# it depend on the which country has less number of creditor for debtor country.
#
# these country debtor has high risk accross creditor
# 1.italy
# 2.portugal
# 3.greece
# 4.irland
#
# And
#
# risk for creditor coundry is depend on how many number of risk and type of risk
# occer in debtor country.
# as we seen all country of creditor has high risk on the top in plot due to 4
# country in debtor with high risk it create "euro debt crisis".

# %% [markdown]
# # result:

# %% [raw]
# these debtor country create crisis due tu having high risk.
# 1.italy
# 2.portugal
# 3.greece
# 4.irlan
